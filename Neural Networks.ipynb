# %% [markdown]
# # Neural Networks

# %% [markdown]
# **Neural networks** are a type of *machine learning* model inspired by the structure and function of the human brain. They consist of interconnected **nodes**, or artificial neurons, that are organized into layers. These neurons process information and make predictions based on patterns in the input data.
#
# Each neuron in a neural network receives input from other neurons, processes this input using a mathematical function, and then passes the result on to other neurons in the next layer. This allows neural networks to model complex, non-linear relationships between inputs and outputs, making them well-suited for tasks such as image and speech recognition, language translation, and decision-making.
#
# The parameters of a neural network can be learned from data through a process called training, in which the network is presented with a large set of input-output examples and the parameters are adjusted so that the network's predictions are as close as possible to the true outputs. This process is typically done using optimization algorithms, such as stochastic gradient descent, to minimize a loss function that measures the difference between the network's predictions and the true outputs.
#
# https://towardsdatascience.com/deep-learning-with-python-neural-networks-complete-tutorial-6b53c0b06af0

# %% [markdown]
# ## Recurrent Neural Network (RNN)
#
# A **Recurrent Neural Network (RNN)** is a type of artificial neural network that is designed to process sequential data, where each sample has connections to the previous sample in the sequence. RNNs have a "memory" that allows them to persist information from the past inputs, making them useful in processing sequences of variable length.
#
# **Long Short-Term Memory (LSTM)** is a type of Recurrent Neural Network (RNN) that is specifically designed to avoid the *vanishing gradient problem* in traditional RNNs. LSTMs have a unique structure that allows them to selectively retain and forget information, effectively solving the issue of balancing short and long-term dependencies in sequential data. This makes them suitable for tasks like language modeling, speech recognition, and sequential decision-making. LSTMs are widely used in time series prediction tasks.
#
# The *vanishing gradient problem* is a phenomenon that occurs in traditional Recurrent Neural Networks (RNNs) when training on long sequences. The issue is that the gradients, which are used to update the network parameters during training, can become very small or even zero as they are backpropagated through many time steps. This can make it difficult or even impossible for the network to learn long-term dependencies between elements in the sequence.
#
# The vanishing gradient problem occurs because traditional RNNs use a simple activation function, such as the **sigmoid function**, that saturates and squashes the activation values into a small range. This means that the gradients passing through the activation function can become very small, making it challenging for the network to learn. The vanishing gradient problem becomes more severe as the depth of the network increases, making it difficult to train deep RNNs.
#
# **ASIDE**: The sigmoid function is given by $$ S(x) = \frac{1}{1 + e^{-x}} $$

# %% [markdown]
# ## Example - LSTM
#
# https://github.com/nachi-hebbar/Time-Series-Forecasting-LSTM/blob/main/RNN_Youtube.ipynb

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Data Visualisation

# %%
df = pd.read_csv('Data/Example_Data/monthly_milk_production.csv',index_col='Date',parse_dates=True)
df.index.freq='MS'

# %%
df.head()
# Out:
#             Production
# Date
# 1962-01-01         589
# 1962-02-01         561
# 1962-03-01         640
# 1962-04-01         656
# 1962-05-01         727

# %%
df.plot(figsize=(10,5));

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
results = seasonal_decompose(df['Production'])
results.plot();

# %%
len(df)
# Out:
# 168

# %% [markdown]
# ## Data Preprocessing

# %%
train = df.iloc[:100]
test = df.iloc[100:]

# %%
len(test)
# Out:
# 68

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# used to give data values between 0-1

# %%
df.head(),df.tail()
# Out:
# (            Production
#  Date
#  1962-01-01         589
#  1962-02-01         561
#  1962-03-01         640
#  1962-04-01         656
#  1962-05-01         727,
#              Production
#  Date
#  1975-08-01         858
#  1975-09-01         817
#  1975-10-01         827
#  1975-11-01         797
#  1975-12-01         843)

# %%
scaler.fit(train)
scaled_train = scaler.transform(train)
scaled_test = scaler.transform(test)

# %%
scaled_train[:10]
# Out:
# array([[0.11320755],
#        [0.02515723],
#        [0.27358491],
#        [0.32389937],
#        [0.54716981],
#        [0.45283019],
#        [0.27358491],
#        [0.14465409],
#        [0.04716981],
#        [0.0754717 ]])

# %%
from keras.preprocessing.sequence import TimeseriesGenerator
# Out:
# 2023-02-02 13:51:06.522000: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# define generator
n_input = 3 # number of months of data at a time
n_features = 1 # we are only using 1 timeseries to make our predictions
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]
print(f'Given the Array: \n{X.flatten()}')
print(f'Predict this y: \n {y}')
# Out:
# Given the Array:
# [0.11320755 0.02515723 0.27358491]
# Predict this y:
#  [[0.32389937]]

# %%
X.shape
# Out:
# (1, 3, 1)

# %%
# We do the same thing, but now instead for 12 months
n_input = 24
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential() # adds layers in a sequence
model.add(LSTM(100, activation='relu', input_shape=(n_input, n_features)))
# 100 neurons
model.add(Dense(1))
model.compile(optimizer='adam', loss='mse')
# Out:
# 2023-02-02 13:51:10.028021: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  SSE4.1 SSE4.2
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 100)               40800
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 40,901
# Trainable params: 40,901
# Non-trainable params: 0
# _________________________________________________________________

# %%
# fit model
model.fit(generator,epochs=100)
# Out:
# Epoch 1/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0165
# Epoch 2/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0119
# Epoch 3/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 4/100
# 76/76 [==============================] - 0s 5ms/step - loss: 0.0122
# Epoch 5/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0106
# Epoch 6/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 7/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0099
# Epoch 8/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0082
# Epoch 9/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0075
# Epoch 10/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0071
# Epoch 11/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0076
# Epoch 12/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0074
# Epoch 13/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0063
# Epoch 14/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0053
# Epoch 15/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0051
# Epoch 16/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0065
# Epoch 17/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0048
# Epoch 18/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0049
# Epoch 19/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 20/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0060
# Epoch 21/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0043
# Epoch 22/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0042
# Epoch 23/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0039
# Epoch 24/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 25/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0342
# Epoch 26/100
# 76/76 [==============================] - 1s 6ms/step - loss: 0.0245
# Epoch 27/100
# 76/76 [==============================] - 1s 6ms/step - loss: 0.0231
# Epoch 28/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0218
# Epoch 29/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0171
# Epoch 30/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0132
# Epoch 31/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0092
# Epoch 32/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0085
# Epoch 33/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0057
# Epoch 34/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0041
# Epoch 35/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0044
# Epoch 36/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 37/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0034
# Epoch 38/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0035
# Epoch 39/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0029
# Epoch 40/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 41/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0028
# Epoch 42/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 43/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0037
# Epoch 44/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 45/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 46/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 47/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0030
# Epoch 48/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 49/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 50/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 51/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0028
# Epoch 52/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 53/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0024
# Epoch 54/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 55/100
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0031
# Epoch 56/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0018
# Epoch 57/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 58/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 59/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0019
# Epoch 60/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0028
# Epoch 61/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0030
# Epoch 62/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 63/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0038
# Epoch 64/100
# 76/76 [==============================] - 1s 6ms/step - loss: 0.0038
# Epoch 65/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0021
# Epoch 66/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 67/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 68/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0020
# Epoch 69/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0025
# Epoch 70/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0021
# Epoch 71/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0024
# Epoch 72/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 73/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 74/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0021
# Epoch 75/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0026
# Epoch 76/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0027
# Epoch 77/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0021
# Epoch 78/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 79/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0016
# Epoch 80/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0018
# Epoch 81/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0023
# Epoch 82/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0026
# Epoch 83/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0019
# Epoch 84/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0027
# Epoch 85/100
# 76/76 [==============================] - 1s 9ms/step - loss: 0.0017
# Epoch 86/100
# 76/76 [==============================] - 1s 11ms/step - loss: 0.0025
# Epoch 87/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0023
# Epoch 88/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0016
# Epoch 89/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0022
# Epoch 90/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0030
# Epoch 91/100
# 76/76 [==============================] - 1s 12ms/step - loss: 0.0017
# Epoch 92/100
# 76/76 [==============================] - 1s 13ms/step - loss: 0.0018
# Epoch 93/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0022
# Epoch 94/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 95/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0017
# Epoch 96/100
# 76/76 [==============================] - 1s 8ms/step - loss: 0.0026
# Epoch 97/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0014
# Epoch 98/100
# 76/76 [==============================] - 1s 7ms/step - loss: 0.0020
# Epoch 99/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0020
# Epoch 100/100
# 76/76 [==============================] - 0s 6ms/step - loss: 0.0020

# %%
loss_per_epoch = model.history.history['loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch)

# %%
last_train_batch = scaled_train[-n_input:] 
# take the last n_input month of values, to make 
# predictions on the 1st test set

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
model.predict(last_train_batch)
# Out:
# 1/1 [==============================] - 0s 21ms/step
# array([[1.0256324]], dtype=float32)

# %%
scaled_test[0]
# Out:
# array([1.04716981])

# %%
test_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(test)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    test_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 26ms/step

# %%
test_predictions
# NOTE: these predictions are in the range 0-1
# we need to convert it back
# Out:
# [array([1.0256324], dtype=float32),
#  array([0.93488276], dtype=float32),
#  array([0.82684046], dtype=float32),
#  array([0.7193871], dtype=float32),
#  array([0.58744717], dtype=float32),
#  array([0.58221143], dtype=float32),
#  array([0.5046539], dtype=float32),
#  array([0.5736567], dtype=float32),
#  array([0.6442536], dtype=float32),
#  array([0.5238115], dtype=float32),
#  array([0.78922135], dtype=float32),
#  array([0.87001675], dtype=float32),
#  array([1.0637925], dtype=float32),
#  array([0.98635864], dtype=float32),
#  array([0.86838526], dtype=float32),
#  array([0.7825871], dtype=float32),
#  array([0.65457225], dtype=float32),
#  array([0.6326994], dtype=float32),
#  array([0.53606254], dtype=float32),
#  array([0.64598924], dtype=float32),
#  array([0.7027007], dtype=float32),
#  array([0.5744269], dtype=float32),
#  array([0.8440666], dtype=float32),
#  array([0.9280256], dtype=float32),
#  array([1.0904989], dtype=float32),
#  array([1.0016909], dtype=float32),
#  array([0.9041772], dtype=float32),
#  array([0.8190231], dtype=float32),
#  array([0.69948393], dtype=float32),
#  array([0.67786086], dtype=float32),
#  array([0.59362686], dtype=float32),
#  array([0.64907956], dtype=float32),
#  array([0.72404283], dtype=float32),
#  array([0.60793453], dtype=float32),
#  array([0.83637875], dtype=float32),
#  array([0.95832604], dtype=float32),
#  array([1.129468], dtype=float32),
#  array([1.0497482], dtype=float32),
#  array([0.9388176], dtype=float32),
#  array([0.8640663], dtype=float32),
#  array([0.7686174], dtype=float32),
#  array([0.7332792], dtype=float32),
#  array([0.6266529], dtype=float32),
#  array([0.72934914], dtype=float32),
#  array([0.77432364], dtype=float32),
#  array([0.6665374], dtype=float32),
#  array([0.88388187], dtype=float32),
#  array([1.0244037], dtype=float32),
#  array([1.1591848], dtype=float32),
#  array([1.0652882], dtype=float32),
#  array([0.9697826], dtype=float32),
#  array([0.8918909], dtype=float32),
#  array([0.8037159], dtype=float32),
#  array([0.77596307], dtype=float32),
#  array([0.68143636], dtype=float32),
#  array([0.7323025], dtype=float32),
#  array([0.78952533], dtype=float32),
#  array([0.6980504], dtype=float32),
#  array([0.8786207], dtype=float32),
#  array([1.0744781], dtype=float32),
#  array([1.2015936], dtype=float32),
#  array([1.1131024], dtype=float32),
#  array([1.0005802], dtype=float32),
#  array([0.9284948], dtype=float32),
#  array([0.8506768], dtype=float32),
#  array([0.8182111], dtype=float32),
#  array([0.7200173], dtype=float32),
#  array([0.79920954], dtype=float32)]

# %%
test.head()
# Out:
#             Production  Predictions
# Date
# 1970-05-01         886   855.404421
# 1970-06-01         859   847.189940
# 1970-07-01         819   825.927942
# 1970-08-01         783   802.389535
# 1970-09-01         740   785.216960

# %%
true_predictions = scaler.inverse_transform(test_predictions)

# %%
test['Predictions'] = true_predictions
# Out:
# /var/folders/42/2w7j46nn3j75crpy2kc1y7vw0000gn/T/ipykernel_3506/4269337381.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   test['Predictions'] = true_predictions

# %%
test.plot(figsize=(14,5))
# Out:
# <AxesSubplot: xlabel='Date'>

# %%
from sklearn.metrics import mean_squared_error
from math import sqrt
rmse=sqrt(mean_squared_error(test['Production'],test['Predictions']))
print(rmse)
# Out:
# 74.23188743545349
