# %% [markdown]
# # LSTM for Smoothed Sunspot Data

# %% [markdown]
# #### Note:
# Initially started using an RNN with a ReLu activation function, which produced some form of results, but they didn't fit well to the data.
#
# I also attempted to use a Sigmoid function & Elu function instead, which seemed to perform worse than the Relu activation function.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import tensorflow as tf
from tensorflow import keras
from keras.callbacks import ModelCheckpoint
# Out:
# 2023-02-28 10:15:21.700996: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
df = pd.read_csv('../Data/Savitzky-Golay Data/SVG_poly1.csv') # importing data for SVG polyorder = 1
X = ((df.Year).values).reshape(-1,1)
y = (df.Sunspot_Number).values
yerr = np.zeros(len(X))

df.drop(columns=['Unnamed: 0'], inplace=True) 
# removes the unnecessary column
df.set_index("Year", inplace=True)

df.head()
# Out:
#           Sunspot_Number
# Year
# 1818.001       34.566570
# 1818.004       34.546053
# 1818.007       34.525535
# 1818.010       34.505017
# 1818.012       34.484499

# %% [markdown]
# ## Data Preprocessing

# %%
limit = 65000
skips = 28 # 1 data point per luna cycle
train_data = df.iloc[:limit:skips] 
validation_data = df.iloc[limit::skips]

# %%
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()

# %%
scaler.fit(train_data)
scaled_train = scaler.transform(train_data)
scaled_test = scaler.transform(validation_data)

# %%
from keras.preprocessing.sequence import TimeseriesGenerator

# %%
# define generator
n_input = 11 * 12 # 11 years 
n_features = 1 # we are only using 1 timeseries to make our predictions
generator = TimeseriesGenerator(scaled_train, scaled_train, length=n_input, batch_size=1)

# %%
X,y = generator[0]
#print(f'Given the Array: \n{X.flatten()}')
#print(f'Predict this y: \n {y}')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM

# %%
# define model
model = Sequential() # adds layers in a sequence
model.add(LSTM(200, activation='relu', return_sequences=True, input_shape=(n_input, n_features))) # maybe try elu?
# 300 neurons, return_sequences=True to add more LSTM layers
model.add(LSTM(100, activation='relu')) # 100 neurons
#model.add(LSTM(75, activation='relu')) # 75 neurons
#model.add(Dense(50, activation='relu')) # additional Dense layer with 50 neurons
model.add(Dense(1))
# 1 layer
model.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=1e-5), loss='mse')
# smaller learning rate = longer running time
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm (LSTM)                 (None, 132, 200)          161600
#
#  lstm_1 (LSTM)               (None, 100)               120400
#
#  dense (Dense)               (None, 1)                 101
#
# =================================================================
# Total params: 282,101
# Trainable params: 282,101
# Non-trainable params: 0
# _________________________________________________________________
# 2023-02-28 10:15:25.486346: I tensorflow/core/platform/cpu_feature_guard.cc:193] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# fit model
epochs = 100

# Define a ModelCheckpoint callback to save the model weights based on validation loss
#checkpoint = ModelCheckpoint('best_weights.h5', monitor='val_loss', save_best_only=True, save_weights_only=True)

# Fit the model to the data, using the ModelCheckpoint callback
history = model.fit(generator, epochs=epochs, batch_size=1) #validation_data=(scaled_test,scaled_test), callbacks=[checkpoint])
# Out:
# Epoch 1/100
# 2190/2190 [==============================] - 192s 87ms/step - loss: 0.0322
# Epoch 2/100
# 2190/2190 [==============================] - 193s 88ms/step - loss: 0.0016
# Epoch 3/100
# 2190/2190 [==============================] - 195s 89ms/step - loss: 7.7326e-04
# Epoch 4/100
# 2190/2190 [==============================] - 196s 89ms/step - loss: 4.1376e-04
# Epoch 5/100
# 2190/2190 [==============================] - 197s 90ms/step - loss: 2.9162e-04
# Epoch 6/100
# 2190/2190 [==============================] - 203s 93ms/step - loss: 2.4809e-04
# Epoch 7/100
# 2190/2190 [==============================] - 197s 90ms/step - loss: 2.3526e-04
# Epoch 8/100
# 2190/2190 [==============================] - 196s 90ms/step - loss: 2.1655e-04
# Epoch 9/100
# 2190/2190 [==============================] - 194s 89ms/step - loss: 2.0173e-04
# Epoch 10/100
# 2190/2190 [==============================] - 261s 119ms/step - loss: 1.8669e-04
# Epoch 11/100
# 2190/2190 [==============================] - 288s 132ms/step - loss: 1.7827e-04
# Epoch 12/100
# 2190/2190 [==============================] - 286s 131ms/step - loss: 1.6867e-04
# Epoch 84/100
# 2190/2190 [==============================] - 168s 77ms/step - loss: 5.9583e-05
# Epoch 85/100
# 2190/2190 [==============================] - 165s 75ms/step - loss: 5.9136e-05
# Epoch 86/100
# 2190/2190 [==============================] - 165s 75ms/step - loss: 5.8651e-05
# Epoch 87/100
# 2190/2190 [==============================] - 167s 76ms/step - loss: 5.7024e-05
# Epoch 88/100
# 2190/2190 [==============================] - 164s 75ms/step - loss: 5.8614e-05
# Epoch 89/100
# 2190/2190 [==============================] - 170s 78ms/step - loss: 5.6995e-05
# Epoch 90/100
# 2190/2190 [==============================] - 164s 75ms/step - loss: 5.5425e-05
# Epoch 91/100
# 2190/2190 [==============================] - 152s 69ms/step - loss: 5.7588e-05
# Epoch 92/100
# 2190/2190 [==============================] - 122s 56ms/step - loss: 5.6228e-05
# Epoch 93/100
# 2190/2190 [==============================] - 116s 53ms/step - loss: 5.6470e-05
# Epoch 94/100
# 2190/2190 [==============================] - 122s 56ms/step - loss: 5.5453e-05
# Epoch 95/100
# 2190/2190 [==============================] - 123s 56ms/step - loss: 5.4055e-05
# Epoch 96/100
# 2190/2190 [==============================] - 130s 59ms/step - loss: 5.4701e-05
# Epoch 97/100
# 2190/2190 [==============================] - 129s 59ms/step - loss: 5.4542e-05
# Epoch 98/100
# 2190/2190 [==============================] - 125s 57ms/step - loss: 5.2572e-05
# Epoch 99/100
# 2190/2190 [==============================] - 124s 57ms/step - loss: 5.4912e-05
# Epoch 100/100
# 2190/2190 [==============================] - 124s 57ms/step - loss: 5.5189e-05

# %%
loss_per_epoch = model.history.history['loss']
#val_loss_per_epoch = model.history.history['val_loss']
plt.plot(range(len(loss_per_epoch)),loss_per_epoch);
#plt.plot(range(len(val_loss_per_epoch)), val_loss_per_epoch)

# %%
last_train_batch = scaled_train[-n_input:] 
# take the last n_input month of values, to make 
# predictions on the 1st test set

# %%
last_train_batch = last_train_batch.reshape((1, n_input, n_features))

# %%
#model.predict(last_train_batch)

y_pred = model.predict(generator)

st = scaled_train.shape[0]
yp = y_pred.shape[0]
c = st - yp
# Note: predictions start after 'n_input' numbers
# Out:
# 2190/2190 [==============================] - 19s 8ms/step

# %%
plt.plot(np.arange(c, st), y_pred, label='predict') 
plt.plot(scaled_train, label='train')
plt.legend();

# %% [markdown]
# #### Comment on plot:
#
# The above plot shows how well our model fits with the training data. As the orange and blue lines almost completely overlap, we can conclude that the model accurately fits with the data. This is a necessary check, as our model will have no chance of predicting future sunspot numbers if it cannot successfully predict the training values.

# %%
validation_predictions = []

first_eval_batch = scaled_train[-n_input:]
current_batch = first_eval_batch.reshape((1, n_input, n_features))

for i in range(len(validation_data)):
    
    # get the prediction value for the first batch
    current_pred = model.predict(current_batch)[0]
    
    # append the prediction into the array
    validation_predictions.append(current_pred) 
    
    # use the prediction to update the batch and remove the first value
    current_batch = np.append(current_batch[:,1:,:],[[current_pred]],axis=1)
# Out:
# 1/1 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 25ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 23ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 24ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 20ms/step

# %%
validation_predictions
# NOTE: these predictions are in the range 0-1
# we need to convert it back
# Out:
# [array([0.09419666], dtype=float32),
#  array([0.09564728], dtype=float32),
#  array([0.09771645], dtype=float32),
#  array([0.10049514], dtype=float32),
#  array([0.10404361], dtype=float32),
#  array([0.10840198], dtype=float32),
#  array([0.11359788], dtype=float32),
#  array([0.11964644], dtype=float32),
#  array([0.12656051], dtype=float32),
#  array([0.1343278], dtype=float32),
#  array([0.14286815], dtype=float32),
#  array([0.15218157], dtype=float32),
#  array([0.1622672], dtype=float32),
#  array([0.17312433], dtype=float32),
#  array([0.18474902], dtype=float32),
#  array([0.19711328], dtype=float32),
#  array([0.21026284], dtype=float32),
#  array([0.22417152], dtype=float32),
#  array([0.2387805], dtype=float32),
#  array([0.2539922], dtype=float32),
#  array([0.2697405], dtype=float32),
#  array([0.2859225], dtype=float32),
#  array([0.3023139], dtype=float32),
#  array([0.3188079], dtype=float32),
#  array([0.33540726], dtype=float32),
#  array([0.3521403], dtype=float32),
#  array([0.36898884], dtype=float32),
#  array([0.3859178], dtype=float32),
#  array([0.4028681], dtype=float32),
#  array([0.4197705], dtype=float32),
#  array([0.43658906], dtype=float32),
#  array([0.45329732], dtype=float32),
#  array([0.46986902], dtype=float32),
#  array([0.4862767], dtype=float32),
#  array([0.5024929], dtype=float32),
#  array([0.51848865], dtype=float32),
#  array([0.5342377], dtype=float32),
#  array([0.5497305], dtype=float32),
#  array([0.5649703], dtype=float32),
#  array([0.579949], dtype=float32),
#  array([0.5946649], dtype=float32),
#  array([0.6091136], dtype=float32),
#  array([0.62329024], dtype=float32),
#  array([0.637188], dtype=float32),
#  array([0.65079695], dtype=float32),
#  array([0.66410345], dtype=float32),
#  array([0.6770898], dtype=float32),
#  array([0.68973476], dtype=float32),
#  array([0.70201385], dtype=float32),
#  array([0.7138897], dtype=float32),
#  array([0.7252919], dtype=float32),
#  array([0.7360491], dtype=float32),
#  array([0.7461087], dtype=float32),
#  array([0.75540465], dtype=float32),
#  array([0.7637171], dtype=float32),
#  array([0.7710183], dtype=float32),
#  array([0.7773068], dtype=float32),
#  array([0.78256476], dtype=float32),
#  array([0.7867662], dtype=float32),
#  array([0.78993344], dtype=float32),
#  array([0.7921009], dtype=float32),
#  array([0.7932261], dtype=float32),
#  array([0.79332095], dtype=float32),
#  array([0.79239756], dtype=float32),
#  array([0.7904708], dtype=float32),
#  array([0.7875558], dtype=float32),
#  array([0.7836726], dtype=float32),
#  array([0.77884257], dtype=float32),
#  array([0.7730909], dtype=float32),
#  array([0.76644355], dtype=float32),
#  array([0.75893664], dtype=float32),
#  array([0.75065154], dtype=float32),
#  array([0.7417], dtype=float32),
#  array([0.73217493], dtype=float32),
#  array([0.7221529], dtype=float32),
#  array([0.7117033], dtype=float32),
#  array([0.70088845], dtype=float32),
#  array([0.68976444], dtype=float32),
#  array([0.6783857], dtype=float32),
#  array([0.66680354], dtype=float32),
#  array([0.6550668], dtype=float32),
#  array([0.6432217], dtype=float32),
#  array([0.63131124], dtype=float32),
#  array([0.61937684], dtype=float32),
#  array([0.60744566], dtype=float32),
#  array([0.59551495], dtype=float32),
#  array([0.5835755], dtype=float32),
#  array([0.57161564], dtype=float32),
#  array([0.55963045], dtype=float32),
#  array([0.54761875], dtype=float32),
#  array([0.5355862], dtype=float32),
#  array([0.5235424], dtype=float32),
#  array([0.5115019], dtype=float32),
#  array([0.49948254], dtype=float32),
#  array([0.48750323], dtype=float32),
#  array([0.47557983], dtype=float32),
#  array([0.46371797], dtype=float32),
#  array([0.4519155], dtype=float32),
#  array([0.4401708], dtype=float32),
#  array([0.42847317], dtype=float32),
#  array([0.41681084], dtype=float32),
#  array([0.40517542], dtype=float32),
#  array([0.3935634], dtype=float32),
#  array([0.38197646], dtype=float32),
#  array([0.3704214], dtype=float32),
#  array([0.35890964], dtype=float32),
#  array([0.34745672], dtype=float32),
#  array([0.33608398], dtype=float32),
#  array([0.32481351], dtype=float32),
#  array([0.31366903], dtype=float32),
#  array([0.30267483], dtype=float32),
#  array([0.29185554], dtype=float32),
#  array([0.28123382], dtype=float32),
#  array([0.27083942], dtype=float32),
#  array([0.26070043], dtype=float32),
#  array([0.25084057], dtype=float32),
#  array([0.2412765], dtype=float32),
#  array([0.23202533], dtype=float32),
#  array([0.22310027], dtype=float32),
#  array([0.21451181], dtype=float32),
#  array([0.20626828], dtype=float32),
#  array([0.19837636], dtype=float32),
#  array([0.1908429], dtype=float32),
#  array([0.18367384], dtype=float32),
#  array([0.17686027], dtype=float32),
#  array([0.17038856], dtype=float32),
#  array([0.16423713], dtype=float32),
#  array([0.15833701], dtype=float32),
#  array([0.15265557], dtype=float32),
#  array([0.14720476], dtype=float32),
#  array([0.14204234], dtype=float32),
#  array([0.13721426], dtype=float32),
#  array([0.13276461], dtype=float32),
#  array([0.12878442], dtype=float32),
#  array([0.12533101], dtype=float32),
#  array([0.12245217], dtype=float32),
#  array([0.12019624], dtype=float32),
#  array([0.11860433], dtype=float32),
#  array([0.1176955], dtype=float32),
#  array([0.11748578], dtype=float32),
#  array([0.11799154], dtype=float32),
#  array([0.11922818], dtype=float32),
#  array([0.12120834], dtype=float32),
#  array([0.12394379], dtype=float32),
#  array([0.12744586], dtype=float32),
#  array([0.1317268], dtype=float32),
#  array([0.13680011], dtype=float32),
#  array([0.14261739], dtype=float32),
#  array([0.14918007], dtype=float32),
#  array([0.15650271], dtype=float32),
#  array([0.16459344], dtype=float32),
#  array([0.17345834], dtype=float32),
#  array([0.18311271], dtype=float32),
#  array([0.19357187], dtype=float32),
#  array([0.20482534], dtype=float32),
#  array([0.21685897], dtype=float32),
#  array([0.22968443], dtype=float32),
#  array([0.24328311], dtype=float32),
#  array([0.25757003], dtype=float32),
#  array([0.27244407], dtype=float32),
#  array([0.28780875], dtype=float32),
#  array([0.30358467], dtype=float32),
#  array([0.3196075], dtype=float32),
#  array([0.3357413], dtype=float32),
#  array([0.3519036], dtype=float32),
#  array([0.36812517], dtype=float32),
#  array([0.3843894], dtype=float32),
#  array([0.4006581], dtype=float32),
#  array([0.41690087], dtype=float32),
#  array([0.43308344], dtype=float32),
#  array([0.44917205], dtype=float32),
#  array([0.46513513], dtype=float32),
#  array([0.48094243], dtype=float32),
#  array([0.49656376], dtype=float32),
#  array([0.5119694], dtype=float32),
#  array([0.52713233], dtype=float32),
#  array([0.54204226], dtype=float32),
#  array([0.55670005], dtype=float32),
#  array([0.5710973], dtype=float32),
#  array([0.58523095], dtype=float32),
#  array([0.599099], dtype=float32),
#  array([0.6126977], dtype=float32),
#  array([0.6260207], dtype=float32),
#  array([0.6390561], dtype=float32),
#  array([0.65178895], dtype=float32),
#  array([0.6642004], dtype=float32),
#  array([0.6762694], dtype=float32),
#  array([0.68796605], dtype=float32),
#  array([0.6992309], dtype=float32),
#  array([0.7099648], dtype=float32),
#  array([0.72012645], dtype=float32),
#  array([0.729646], dtype=float32),
#  array([0.738351], dtype=float32),
#  array([0.7461502], dtype=float32),
#  array([0.752988], dtype=float32),
#  array([0.75885546], dtype=float32),
#  array([0.7637302], dtype=float32),
#  array([0.7675781], dtype=float32),
#  array([0.7703968], dtype=float32),
#  array([0.7722529], dtype=float32),
#  array([0.7731105], dtype=float32),
#  array([0.77298504], dtype=float32),
#  array([0.7718878], dtype=float32),
#  array([0.7698336], dtype=float32),
#  array([0.76684], dtype=float32),
#  array([0.7629276], dtype=float32),
#  array([0.7581186], dtype=float32),
#  array([0.7524392], dtype=float32),
#  array([0.74591696], dtype=float32),
#  array([0.7385822], dtype=float32),
#  array([0.7305022], dtype=float32),
#  array([0.72178096], dtype=float32),
#  array([0.7125118], dtype=float32),
#  array([0.70277476], dtype=float32),
#  array([0.6926393], dtype=float32),
#  array([0.68216693], dtype=float32),
#  array([0.67141426], dtype=float32),
#  array([0.66043496], dtype=float32),
#  array([0.6492785], dtype=float32),
#  array([0.637992], dtype=float32),
#  array([0.6266192], dtype=float32),
#  array([0.6152006], dtype=float32),
#  array([0.60377306], dtype=float32),
#  array([0.5923319], dtype=float32),
#  array([0.58087814], dtype=float32),
#  array([0.56939936], dtype=float32),
#  array([0.55788815], dtype=float32),
#  array([0.54634285], dtype=float32),
#  array([0.53476703], dtype=float32),
#  array([0.5231683], dtype=float32),
#  array([0.51156], dtype=float32),
#  array([0.49995735], dtype=float32),
#  array([0.48837975], dtype=float32),
#  array([0.47684655], dtype=float32),
#  array([0.46535826], dtype=float32),
#  array([0.45391536], dtype=float32),
#  array([0.44252098], dtype=float32),
#  array([0.43117407], dtype=float32),
#  array([0.41986573], dtype=float32),
#  array([0.40858668], dtype=float32),
#  array([0.39733076], dtype=float32),
#  array([0.3860959], dtype=float32),
#  array([0.37488538], dtype=float32),
#  array([0.36370665], dtype=float32),
#  array([0.35257128], dtype=float32),
#  array([0.3414945], dtype=float32),
#  array([0.33049485], dtype=float32),
#  array([0.31959456], dtype=float32),
#  array([0.3088171], dtype=float32),
#  array([0.29818568], dtype=float32),
#  array([0.287724], dtype=float32),
#  array([0.27745485], dtype=float32),
#  array([0.2674019], dtype=float32),
#  array([0.2575892], dtype=float32),
#  array([0.24803068], dtype=float32),
#  array([0.23874027], dtype=float32),
#  array([0.22973911], dtype=float32),
#  array([0.22104385], dtype=float32),
#  array([0.21266808], dtype=float32),
#  array([0.20462137], dtype=float32),
#  array([0.19691144], dtype=float32),
#  array([0.18954694], dtype=float32),
#  array([0.18253344], dtype=float32),
#  array([0.17585787], dtype=float32),
#  array([0.16950943], dtype=float32),
#  array([0.16345523], dtype=float32),
#  array([0.1576349], dtype=float32),
#  array([0.15202479], dtype=float32),
#  array([0.14665009], dtype=float32),
#  array([0.14156583], dtype=float32),
#  array([0.13681322], dtype=float32),
#  array([0.13243958], dtype=float32),
#  array([0.12853913], dtype=float32),
#  array([0.12516345], dtype=float32),
#  array([0.12235726], dtype=float32),
#  array([0.12016937], dtype=float32),
#  array([0.11863029], dtype=float32),
#  array([0.11776073], dtype=float32),
#  array([0.11757643], dtype=float32),
#  array([0.11809342], dtype=float32),
#  array([0.119326], dtype=float32),
#  array([0.12128636], dtype=float32),
#  array([0.12398592], dtype=float32),
#  array([0.12743586], dtype=float32),
#  array([0.13164811], dtype=float32),
#  array([0.13663605], dtype=float32),
#  array([0.14235291], dtype=float32),
#  array([0.14879932], dtype=float32),
#  array([0.15599002], dtype=float32),
#  array([0.16393344], dtype=float32),
#  array([0.17263532], dtype=float32),
#  array([0.18211332], dtype=float32),
#  array([0.19238263], dtype=float32),
#  array([0.203433], dtype=float32),
#  array([0.21525279], dtype=float32),
#  array([0.22784908], dtype=float32),
#  array([0.24121417], dtype=float32),
#  array([0.25527725], dtype=float32),
#  array([0.26993752], dtype=float32),
#  array([0.28509653], dtype=float32),
#  array([0.30067682], dtype=float32),
#  array([0.31656212], dtype=float32),
#  array([0.33261696], dtype=float32),
#  array([0.34866747], dtype=float32),
#  array([0.36475885], dtype=float32),
#  array([0.3808815], dtype=float32),
#  array([0.3970089], dtype=float32),
#  array([0.41311345], dtype=float32),
#  array([0.42916116], dtype=float32),
#  array([0.4451177], dtype=float32),
#  array([0.46095097], dtype=float32),
#  array([0.47662994], dtype=float32),
#  array([0.49212456], dtype=float32),
#  array([0.5074049], dtype=float32),
#  array([0.52244157], dtype=float32),
#  array([0.53722113], dtype=float32),
#  array([0.55174637], dtype=float32),
#  array([0.5660075], dtype=float32),
#  array([0.5800011], dtype=float32),
#  array([0.593725], dtype=float32),
#  array([0.60717523], dtype=float32),
#  array([0.6203458], dtype=float32),
#  array([0.6332278], dtype=float32),
#  array([0.6458079], dtype=float32),
#  array([0.6580677], dtype=float32),
#  array([0.66998565], dtype=float32),
#  array([0.6815151], dtype=float32),
#  array([0.6926028], dtype=float32),
#  array([0.7031811], dtype=float32),
#  array([0.713215], dtype=float32),
#  array([0.7226294], dtype=float32),
#  array([0.73122513], dtype=float32),
#  array([0.73894125], dtype=float32),
#  array([0.7457191], dtype=float32),
#  array([0.7515444], dtype=float32),
#  array([0.7563934], dtype=float32),
#  array([0.76023185], dtype=float32),
#  array([0.7630327], dtype=float32),
#  array([0.7648875], dtype=float32),
#  array([0.7657608], dtype=float32),
#  array([0.76566625], dtype=float32),
#  array([0.7646152], dtype=float32),
#  array([0.76262236], dtype=float32),
#  array([0.7597051], dtype=float32),
#  array([0.7558842], dtype=float32),
#  array([0.75118273], dtype=float32),
#  array([0.74562645], dtype=float32),
#  array([0.7392431], dtype=float32),
#  array([0.7320631], dtype=float32),
#  array([0.7241399], dtype=float32)]

# %%
true_predictions = scaler.inverse_transform(validation_predictions)

# %%
validation_data['Predictions'] = true_predictions
# Out:
# /var/folders/f6/ysbvf32j6ks_1h83gmlfzghw0000gn/T/ipykernel_45498/2311742674.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   validation_data['Predictions'] = true_predictions

# %%
validation_data.plot(figsize=(14,5));

# %% [markdown]
# #### Comment on plot:
#
# The predictions for future sunspot number seem to have a period which is close to the observed period (but not perfect), and the amplitude is still too high. I can try running again with more epochs or more neurons and see what happens.
#
# **Edit**: run with 300 neurons produced a similar result to one with 200 neurons. Next I will try running with 200 neurons again, but for 100 epochs.
#
# **Edit 2**: run with 200 neurons for 87 epochs produced results with a smaller amplitude, but the timing of the peaks were incorrect.
#
# **Edit 3**: run with 300 neurons for 78 epochs --> fitting not appropriate, previous attempt was the best.
#
# **Edit 4**: run with 100 neurons in layer 1, 100 neurons in layer 2, for 100 epochs --> also predicting for a longer period. LSTM does not perform too badly, however it has a problem predicting how low the sunspot numbers go and the amplitudes.
